# %%
"hello world"
# Out:
# 'hello world'

# %%
print("helloo")
# Out:
# helloo

# %%
name = "ayse"

# %%
type(name)
# Out:
# str

# %%
"atil restaurant"
# Out:
# 'atil restaurant'

# %% [markdown]
# 'atil '

# %%
"atil's restaurant"
# Out:
# "atil's restaurant"

# %%
name.capitalize()
# Out:
# 'Ayse'

# %%
help(name.count)
# Out:
# Help on built-in function count:
#
# count(sub[, start[, end]], /) method of builtins.str instance
#     Return the number of non-overlapping occurrences of substring sub in string S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.

# %%
name.count("a")
# Out:
# 1

# %%
name.upper()
# Out:
# 'AYSE'

# %%
x = 10
y = 5

# %%
x+y
# Out:
# 15

# %%
z = x+y

# %%
z
# Out:
# 15

# %%
nameUpper = name.upper()

# %%
nameUpper
# Out:
# 'AYSE'

# %%
len(name) #length
# Out:
# 4

# %%
print("atil samancıoğlu")
# Out:
# atil samancıoğlu

# %%
print("atil \nsamancıoğlu") # \n -------> new line escape character
# Out:
# atil
# samancıoğlu

# %%
print("atil \tsamancıoğlu") # \t -------> tab escape character
# Out:
# atil 	samancıoğlu

# %% [markdown]
# #### INDEX

# %%
myString = "hello python"

# %%
myString[4]
# Out:
# 'o'

# %%
myString[11]
# Out:
# 'n'

# %%
len(myString)
# Out:
# 12

# %%
myString[len(myString) -1]
# Out:
# 'n'

# %%
myString[-1] ## -1 son karakteri - 2 sondan 2.karakteri pythona özel durum
# Out:
# 'n'

# %%
myString[-2]
# Out:
# 'o'

# %%
name = "ayşegül"

# %%
surname = "yılmaz"

# %%
fullname = name + " " + surname

# %%
fullname
# Out:
# 'ayşegül yılmaz'

# %%
fullname * 5
# Out:
# 'ayşegül yılmazayşegül yılmazayşegül yılmazayşegül yılmazayşegül yılmaz'

# %%
100 * "a"
# Out:
# 'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa'

# %%
barcode = "ABCDE123123982"

# %%
barcode[0] + barcode[1] +barcode[2]
# Out:
# 'ABC'

# %%
#ama bu hep böyle indexle birleştirilmez o yüzden slicing(dilimleme) işlemleri var -------> starting index , stopping index , stepping size

# %%
barcode
# Out:
# 'ABCDE123123982'

# %%
barcode[::] #değer vermedik
# Out:
# 'ABCDE123123982'

# %%
#barcode[#starting index:#stopping index :#stepping size] starting kaçtan başlayalım stopping kaçta duralım stepping de kaçar kaçar gidelim

# %%
barcode[3::]
# Out:
# 'DE123123982'

# %%
barcode[:3:]
# Out:
# 'ABC'

# %%
barcode[:5:]
# Out:
# 'ABCDE'

# %%
barcode
# Out:
# 'ABCDE123123982'

# %%
barcode[::2]
# Out:
# 'ACE2138'

# %%
barcode[::3]
# Out:
# 'AD228'

# %%
barcode[3:5:]
# Out:
# 'DE'

# %%
barcode[3:5]
# Out:
# 'DE'

# %%
barcode[::-1] #stringi ters çevirir
# Out:
# '289321321EDCBA'

# %%
name = "world wide"

# %%
name.index("l") #index methodu karakteri en küçük index hangisi ise onu gösterir
# Out:
# 3

# %%
name.split() #bölmek
# Out:
# ['world', 'wide']

# %%
type(name.split())
# Out:
# list
