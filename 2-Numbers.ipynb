# %% [markdown]
# ## data type

# %%
type(10) ##type içinde yazılan ifadenin veri tipini verir.
# Out:
# int

# %%
type(20.0)
# Out:
# float

# %%
#float -------------> floating point

# %%
type(-100)
# Out:
# int

# %%
type(2.5)
# Out:
# float

# %%
myFloat = 1.34432426 #camelCase yazı tipi

# %%
my_Float=3.14 #snake_case yazı tipi

# %%
type(10/2)
# Out:
# float

# %%
type(4.5-2)
# Out:
# float

# %%
4.2*3-5
# Out:
# 7.600000000000001

# %%
2-10*2
# Out:
# -18

# %%
10 % 3  #remainder
# Out:
# 1
