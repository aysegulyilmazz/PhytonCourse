# %%
myList = [10,"a","b",3.14] #list yapısı

# %%
myList[0]
# Out:
# 10

# %%
myList[0] = 100

# %%
myList
# Out:
# [100, 'a', 'b', 3.14]

# %%
#tuple

# %%
myTuple = ( 10, "a" , "b", 3.14)

# %%
type(myTuple)
# Out:
# tuple

# %%
myTuple[0]
# Out:
# 10

# %%
# myTuple[0] = 100 yapmaz immutability

# %%
myTuple
# Out:
# (10, 'a', 'b', 3.14)

# %%
myTuple.index("a")
# Out:
# 1

# %%
myTuple.count("b")
# Out:
# 1

# %%
resultTuple = (10,20,30)

# %%
resultTuple
# Out:
# (10, 20, 30)

# %%
resultList = list(resultTuple)

# %%
resultList
# Out:
# [10, 20, 30]
