# %% [markdown]
# ### VARIABLES

# %%
3+5
# Out:
# 8

# %% [markdown]
# ###

# %%
4*3
# Out:
# 12

# %%
900/4
# Out:
# 225.0

# %%
10-100
# Out:
# -90

# %%
5*5*5*5*5
# Out:
# 3125

# %%
age = 30

# %%
age
# Out:
# 30

# %%
age * 5
# Out:
# 150

# %%
age / 2
# Out:
# 15.0
