# %%
# UNİQUE ELEMENTS , UNORDERED

# %%
myList = [10,20,30,10,20,40,10,20,40]

# %%
len(myList)
# Out:
# 9

# %%
myList
# Out:
# [10, 20, 30, 10, 20, 40, 10, 20, 40]

# %%
mySet = set(myList) #setin içinde elemandan sadece 1 tane oluyor.

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet = {10,20,30,40,10,20,40,10,20,40}

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet.add(10)

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet.add(50)

# %%
mySet
# Out:
# {10, 20, 30, 40, 50}

# %%
mySet2 = {30,40,50,60,70}

# %%
mySet2
# Out:
# {30, 40, 50, 60, 70}

# %%
mySet.union(mySet2) #union birleştirme iki seti birleştiriyor
# Out:
# {10, 20, 30, 40, 50, 60, 70}

# %%
mySet.intersection(mySet2) # intersection kesiştirme
# Out:
# {30, 40, 50}

# %%
countryList = ["de","fr","tr","tr","fr","tr","de","nl"]

# %%
len(countryList)
# Out:
# 8

# %%
len(set(countryList))
# Out:
# 4

# %%
emptyList = []

# %%
emptyList.append(10)
emptyList.append(20)
emptyList.append(30)

# %%
emptyList
# Out:
# [10, 20, 30]

# %%
emptySet = {}

# %%
type(emptySet)
# Out:
# dict

# %%
emptySet = set()

# %%
type(emptySet)
# Out:
# set

# %%
len(emptySet)
# Out:
# 0

# %%
emptySet.add(10)
emptyList.add(20)
emptyList.add(30)

# %%
emptySet
# Out:
# set()

# %%
emptyList = list()

# %%
emptyList.append(10)
emptyList.append(20)
emptyList.append(30)

# %%
emptyList
# Out:
# [10, 20, 30]

# %%
emptyDictionary = dict()

# %%
emptyDictionary["a"] = 10
emptyDictionary["b"] = 20

# %%
emptyDictionary
# Out:
# {'a': 10, 'b': 20}
