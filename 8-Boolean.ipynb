# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
myBoolean = True

# %%
type(myBoolean)
# Out:
# bool

# %%
myBoolean = False

# %%
5 > 3
# Out:
# True

# %%
3 > 4
# Out:
# False

# %%
yaş = int(input("Yaşınızı giriniz."))
# Out:
# Yaşınızı giriniz. 30

# %%
yaş > 18
# Out:
# True
