# %%
myString = "hello world"

# %%
myString.split()
# Out:
# ['hello', 'world']

# %%
type(myString.split())
# Out:
# list

# %%
# list bir veri yapsıdır koleksiyondur içinde birden fazla veriyi tutar hello tutuyor world tutuyor örneğin

# %%
# myString[0] = "a" ---------> myString in tek bir elemanını değiştiremezsin immutable

# %% [markdown]
# # list

# %%
myList = [10,20,30]

# %%
type(myList)
# Out:
# list

# %%
x = 10
y = 20
z = 40

# %%
myList = [x,y,z]

# %%
myList
# Out:
# [10, 20, 40]

# %%
myList = [10,20,30,40,50,60,70]

# %%
type(myList)
# Out:
# list

# %%
type(myList[0])
# Out:
# int

# %%
myList[0] = 100 #mutable

# %%
myList
# Out:
# [100, 20, 30, 40, 50, 60, 70]

# %%
len(myList)
# Out:
# 7

# %%
myList[len(myList) -1]
# Out:
# 70

# %%
myList[-1]
# Out:
# 70

# %%
myList[-2]
# Out:
# 60

# %%
myList.append(80) #----------> 80 i ekliyoruz append ekleme ama sona direkt ekliyor

# %%
myList.count(100) #count fonksiyonu sayıyor
# Out:
# 1

# %%
myList
# Out:
# [100, 20, 30, 40, 50, 60, 70, 80]

# %%
myList.insert(2,35) #istediğim yeri istediğim veriyi insert ile ekliyorum.

# %%
myList
# Out:
# [100, 20, 35, 30, 40, 50, 60, 70, 80]

# %%
myList.pop() # pop son elemanı atar
# Out:
# 80

# %%
myList
# Out:
# [100, 20, 35, 30, 40, 50, 60, 70]

# %%
myList.remove(40) # istediğimiz elemanı kaldırıyor
myList
# Out:
# [100, 20, 35, 30, 50, 60, 70]

# %%
myList.reverse() # tersine çevirir

# %%
myList
# Out:
# [70, 60, 50, 30, 35, 20, 100]

# %%
myList.sort() #diziyor ama mantıga göre sayıları küçükten büyüğe

# %%
myList
# Out:
# [20, 30, 35, 50, 60, 70, 100]

# %%
x = input("ENTER X : ")
# Out:
# ENTER X :  10

# %%
x
type(x)
# Out:
# str

# %%
y = input("ENTER y : ")
# Out:
# ENTER y :  20

# %%
y
# Out:
# '20'

# %%
z = input("ENTER z : ")
# Out:
# ENTER z :  30

# %%
inputList = []

# %%
inputList
# Out:
# []

# %%
type(inputList)
# Out:
# list

# %%
len(inputList)
# Out:
# 0

# %%
inputList.append(x)
inputList.append(y)
inputList.append(z)
inputList
# Out:
# ['10', '20', '30']

# %%
inputList[0]
# Out:
# '10'

# %%
inputList[0]*2
# Out:
# '1010'

# %%
type(inputList[0])
# Out:
# str

# %%
# Veri Tipi Dönüştürme
myInteger = 50

# %%
str(myInteger)
# Out:
# '50'

# %%
myString = "40"

# %%
int(myString)
# Out:
# 40

# %%
float(myString)
# Out:
# 40.0

# %%
int(inputList[0]) *2
# Out:
# 20

# %%
nameList = ["ayşe ", "arda" ,"tuna"]

# %%
type(nameList)
# Out:
# list

# %%
floatList = [ 3.14 , 2.5 , 10.2 ,100.124]

# %%
type(floatList)
# Out:
# list

# %%
mixedList = ["arda" , 100 , 3.14]

# %%
type(mixedList)
# Out:
# list

# %%
list1 = [10 , 30 , 50]
list2 = [20 , 40 , 60]

# %%
list3 = list1 + list2
list3
# Out:
# [10, 30, 50, 20, 40, 60]

# %%
list3.sort()
list3
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
list1 *2
# Out:
# [10, 30, 50, 10, 30, 50]

# %%
mixedList
# Out:
# ['arda', 100, 3.14]

# %%
mixedList[0]
# Out:
# 'arda'

# %%
type(mixedList[0])
# Out:
# str

# %% [markdown]
# # NESTED LİST

# %%
myNestedList = [ 10 , 20, 3.14 , "atil" , [1,2,3]]

# %%
myNestedList[0]
# Out:
# 10

# %%
myNestedList[1]
# Out:
# 20

# %%
myNestedList[2]
# Out:
# 3.14

# %%
myNestedList[3]
# Out:
# 'atil'

# %%
myNestedList[4]
# Out:
# [1, 2, 3]

# %%
smallList = myNestedList[4]

# %%
smallList
# Out:
# [1, 2, 3]

# %%
smallList[0]
# Out:
# 1

# %%
type(smallList)
# Out:
# list

# %%
myNestedList[4][0]
# Out:
# 1

# %%
myNestedList[4][1]
# Out:
# 2

# %%
myNestedList[4][2]
# Out:
# 3

# %%
lastList = ["a","b",["c","d","e"],"f"]

# %%
len(lastList)
# Out:
# 4

# %%
lastList[0]
# Out:
# 'a'

# %%
lastList[1]
# Out:
# 'b'

# %%
lastList[2]
# Out:
# ['c', 'd', 'e']

# %%
lastList[3]
# Out:
# 'f'

# %%
lastList[2][1]
# Out:
# 'd'

# %%
firstList = [10,20,30,40,50,60,70]

# %%
firstList[::]
# Out:
# [10, 20, 30, 40, 50, 60, 70]
